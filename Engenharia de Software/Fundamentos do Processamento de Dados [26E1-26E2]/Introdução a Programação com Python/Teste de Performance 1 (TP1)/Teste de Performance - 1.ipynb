# %% [markdown]
# # Teste de Performance - 1

# %% [markdown]
# ### Exercício 1 – Importância da Programação e Comentários
# Uma consultoria de tecnologia está integrando novos desenvolvedores e deseja padronizar a documentação inicial de seus scripts. O setor de treinamento precisa que todo código comece com uma explicação clara sobre por que a automação via Python é vital para a eficiência da empresa. O impacto esperado é que novos colaboradores compreendam o valor do código que estão escrevendo desde o primeiro dia através de boas práticas de documentação.
#
# **Tarefa**
#
# No seu bloco de código Python no Deepnote, utilize o caractere `#` para escrever um comentário explicativo sobre a importância da programação.

# %%
# A programação é essencial para automatizar tarefas e processos, reduzir erros humanos e pricipamente reduzir o tempo de execução de tarefas repetitivas. E claro tudo isso trá um ganho financeiro para a empresa.
# No contexto em questão, o uso de Python permite criar soluções rápidas, escaláveis e de fácil manutenção, isso por conta da sua facilidade de uso. Garantindo padronização, produtividade e geração de valor desde o início do desenvolvimento.

# %% [markdown]
# ### Exercício 2 – Processo de Escrita e Hello World
# O departamento de marketing de uma rede de cinemas quer testar a interface de seus novos totens de autoatendimento. Para isso, o setor de desenvolvimento precisa de um script simples que valide a saída de texto padrão do sistema para garantir que o hardware está processando comandos corretamente. O programa deve exibir a saudação oficial solicitada pela gerência na tela do terminal.
#
# **Tarefa**
#
# Escreva um programa no Deepnote que utilize a função `print()` para exibir a mensagem: "Olá Mundo! Bem-vindo ao Cinema Digital".

# %%
print("Olá mundo! Bem-vindo ao Cinema Digital")
# Out:
# Olá mundo! Bem-vindo ao Cinema Digital

# %% [markdown]
# ### Exercício 3 – Abordagem Programática e Atribuição
# O setor de RH de uma escola de cursos livres deseja preparar o sistema para o registro de novos alunos. O coordenador pedagógico solicitou que os dados sejam organizados em variáveis separadas antes de qualquer processamento futuro. O cenário envolve o armazenamento do nome de uma disciplina e o código da turma. O impacto esperado é a organização estruturada das informações acadêmicas.
#
# **Tarefa**
#
# Declare uma variável chamada `disciplina` com o valor `"Python"` e uma variável chamada `turma` com o valor `101`. Utilize dois comandos `print()` separados para exibir o conteúdo de cada variável no terminal.

# %%
disciplina = "Python"
turma = 101

print(disciplina)
print(turma)
# Out:
# Python
# 101

# %% [markdown]
# ### Exercício 4 – Fluxo IPO: Entrada, Processamento e Saída
# Uma equipe de logística precisa de um pequeno utilitário para registrar dados de estoque. O planejamento exige que o código siga uma estrutura organizada de entrada, processamento e saída (IPO). Para este teste, os dados de entrada são o peso de uma caixa (80kg) e a quantidade (10 unidades). O impacto esperado é a facilidade de manutenção do código através de um fluxo lógico claro.
#
# **Tarefa**
#
# Crie um programa que siga o fluxo IPO:
# 1. **Entrada:** Defina as variáveis `peso_unidade = 80` e `quantidade = 10`.
# 2. **Processamento:** Crie a variável `peso_total` que multiplica o peso pela quantidade.
# 3. **Saída:** Exiba o valor armazenado em `peso_total` usando o comando `print()`.

# %%
peso_unidade = 80
quantidade = 10
peso_total = peso_unidade * quantidade
print(peso_total)
# Out:
# 800

# %% [markdown]
# ### Exercício 5 – Atribuição de Variáveis de Inventário
# O gerente de um pequeno hortifruti deseja digitalizar o controle de seus itens mais vendidos. O cenário exige que o preço de uma fruta e sua quantidade em estoque sejam armazenados para consulta rápida. Os valores são atribuídos diretamente conforme o fechamento do dia. O impacto esperado é facilitar a leitura do inventário por qualquer funcionário que acesse o sistema.
#
# **Tarefa**
#
# No Deepnote, atribua os seguintes valores: `quantidade_macas` recebe `150` e `preco_maca` recebe `5.99`. Utilize a função `print()` para exibir primeiro a quantidade e depois o preço, em linhas separadas.

# %%
quantidade_macas = 150
preco_maca = 5.99
print(str(quantidade_macas) + "\n" + str(preco_maca))
# Out:
# 150
# 5.99

# %% [markdown]
# ### Exercício 6 – Tipos Básicos: Int e Float no Financeiro
# Um analista financeiro está criando um controle de contratos para uma microempresa. O cenário exige a distinção clara entre números inteiros (contagem de contratos) e números decimais (valores monetários) para garantir precisão contábil. O programa deve armazenar esses dados e confirmar os tipos de dados processados.
#
# **Tarefa**
#
# Crie as variáveis `contratos = 12` e `faturamento = 2500.50`. Use a função `print()` para exibir o tipo da variável `contratos` e o tipo da variável `faturamento` utilizando a função `type()`.

# %%
contratos = 12
faturamento = 2500.50
print("contratos =", contratos, "-->", type(contratos), "\nfaturamento =", faturamento, "-->", type(faturamento))
# Out:
# contratos = 12 --> <class 'int'>
# faturamento = 2500.5 --> <class 'float'>

# %% [markdown]
# ### Exercício 7 – Tipos Básicos: Booleanos em Segurança
# Uma empresa de segurança patrimonial precisa de um verificador para o estado dos sensores de um armazém. O cenário envolve apenas dois estados possíveis: ativo ou inativo. O programa deve guardar o estado atual do monitoramento para que outros sistemas possam ler essa informação lógica.
#
# **Tarefa**
#
# Crie uma variável chamada `sensor_ativo` e atribua a ela o valor booleano `True`. Em seguida, exiba o valor da variável no terminal utilizando `print()`. Altere seu valor para `False` e imprima novamente.

# %%
sensor_ativo = True
print(sensor_ativo)
sensor_ativo = False
print(sensor_ativo)
# Out:
# True
# False

# %% [markdown]
# ### Exercício 8 – Operações Aritméticas: Soma de Receita
# O setor de vendas de uma loja de eletrônicos precisa calcular a receita bruta do período da manhã. O cenário de negócio envolve somar o total vendido em smartphones e o total vendido em acessórios. Os dados são fornecidos pelo relatório de vendas do caixa. O impacto esperado é a agilidade no fechamento de caixa parcial.
#
# **Tarefa**
#
# Defina `venda_smartphones = 5400.00` e `venda_acessorios = 1250.50`. Crie uma variável `receita_total` que realize a soma e exiba o resultado final.

# %%
venda_smartphones = 5400.00
venda_acessorios = 1250.50
receita_total = venda_smartphones + venda_acessorios
print(receita_total)
# Out:
# 6650.5

# %% [markdown]
# ### Exercício 9 – Operações de Subtração de Saldo
# O setor de contas a pagar de uma loja precisa calcular o saldo disponível após o pagamento de uma fatura de fornecedor. O saldo atual em conta é de 10.000 reais e a fatura é de 3.500 reais. O impacto esperado é o controle financeiro imediato das saídas de capital da empresa.
#
# **Tarefa**
#
# Crie as variáveis `saldo_atual = 10000` e `valor_fatura = 3500`. Calcule o saldo restante e armazene em `saldo_final`. Exiba o valor de `saldo_final`.

# %%
saldo_atual = 10000
valor_fatura = 3500
saldo_final = saldo_atual - valor_fatura
print("R$", saldo_final)
# Out:
# R$ 6500

# %% [markdown]
# ### Exercício 10 – Multiplicação e Divisão de Preços
# Um supermercado vende fardos de produtos e o gerente precisa saber o preço unitário para etiquetagem. O cenário envolve um fardo de 6 unidades que custa 24.00 reais. O programa deve calcular o custo de uma única unidade para automação da precificação de gôndola.
#
# **Tarefa**
#
# Defina `preco_fardo = 24.0` e `unidades = 6`. Calcule o `preco_unitario` e exiba o resultado.

# %%
preco_fardo = 24.0
unidades = 6
preco_unitario = preco_fardo / unidades
print(f"R$ {preco_unitario:.2f}") #MueHEHEHE
# Out:
# R$ 4.00

# %% [markdown]
# ## A partir deste ponto, os exercícios podem ser feitos em grupo.

# %% [markdown]
# ### Exercício 11 – Otimização de Carga e Estabilidade de Frete
# Um operador logístico trabalha com o transporte de insumos industriais em caminhões de pequeno porte. Cada saca de polímero pesa exatamente 65kg, e o veículo possui um limite de carga útil de 550kg. O impacto esperado é garantir que o caminhão nunca ultrapasse sua capacidade máxima, transportando apenas unidades inteiras para evitar o deslocamento perigoso da carga durante o trajeto.
#
# **Tarefa:**
# Com base na capacidade de 550kg e no peso unitário de 65kg, desenvolva um código que calcule o número máximo de sacas que podem ser embarcadas em um caminhão sem exceder o limite, bem como a porcentagem de ocupação do peso do caminhão . O resultado deve ser armazenado em uma variável que represente a capacidade real, e outra com a porcentagem, ambas exibidas no console.

# %%
limite_carga_veiculo = 550
peso_unidade_saca = 65
capacidade_real = (limite_carga_veiculo // peso_unidade_saca) * peso_unidade_saca
capacidade_porcentagem = (capacidade_real * 100) / limite_carga_veiculo
print(f"{capacidade_real / peso_unidade_saca:.0f} carga{'s' if capacidade_real / peso_unidade_saca > 1 else '' } com um total de {capacidade_real:.2f}kg, ocupando {capacidade_porcentagem:.1f}% da capacidade máxima do veículo.") #HEHE ninguém viu condicional aqui
# Out:
# 8 cargas com um total de 520.00kg, ocupando 94.5% da capacidade máxima do veículo.

# %% [markdown]
# ### Exercício 12 – Sincronização de Turnos e Manutenção Preventiva
# Uma planta petroquímica opera em ciclos ininterruptos de produção que duram 8 dias. Após um período de 125 dias de operação contínua, o engenheiro de manutenção precisa identificar em qual estágio do ciclo atual (de 0 a 7) a planta se encontra para agendar uma parada técnica, que deve ser feita apenas no fim do ciclo. O impacto esperado é a precisão no cronograma de manutenção preditiva.
#
# **Tarefa:**
# Considerando o total de 125 dias decorridos e a periodicidade de 8 dias, escreva um programa que determine a fase atual da operação dentro do ciclo e com quantos dias decorridos ao todo poderemos ter a parada técnica. Exiba com duas variáveis o valor resultante que indica o dia atual do ciclo e a quantidade total de dias decorridos até a parada.

# %%
duracao_ciclo_em_dias = 8
dias_decorridos_no_montante_total = 125
dia_atual_do_ciclo = dias_decorridos_no_montante_total % duracao_ciclo_em_dias #de 0 a 7, totalizando 8 passos
dias_faltantes_para_o_ciclo_fechar = duracao_ciclo_em_dias - dia_atual_do_ciclo
dia_da_parada_tecnica_no_montante_total = dias_decorridos_no_montante_total + dias_faltantes_para_o_ciclo_fechar
print("Dias decorridos:", dias_decorridos_no_montante_total)
print("Dia da parada técnica:", dia_da_parada_tecnica_no_montante_total)
# Out:
# Dias decorridos: 125
# Dia da parada técnica: 128

# %% [markdown]
# ### Exercício 13 – Engenharia Reversa de Tributação e Logística
# Um analista financeiro precisa calcular o custo de faturamento de uma licença de software internacional que custa 2.500 reais. Sobre esse valor base, deve incidir uma alíquota de serviço de 5%. Somente após o cálculo do valor tributado, deve-se somar uma taxa de suporte fixo de 150 reais. O impacto esperado é a emissão de notas fiscais corretas onde a taxa de suporte não sofra incidência tributária.
#
# **Tarefa:**
# Defina os valores para custo base (2500), alíquota (0.05) e suporte (150). Calcule, em apenas uma linha utilizando parênteses, o valor final que o cliente deverá pagar, garantindo que a ordem das operações respeite a regra de negócio descrita. Exiba o total final.

# %%
custo_base = 2500 
aliquota = 0.05
suporte = 150
valor_final = (custo_base + (custo_base * aliquota)) + suporte
print(f"Total final: R$ {valor_final:.2f}".replace(".", ",")) #MuaHAHAHA
# Out:
# Total final: R$ 2775,00

# %% [markdown]
# ### Exercício 14 – Auditoria de Desempenho e Eficiência de Ativos
# O gestor de um parque industrial monitora o tempo de uso de braços robóticos em minutos para calcular o custo de depreciação. Um equipamento registrou 345 minutos de atividade, enquanto outro registrou 3 horas e 08 minutos. Para o dashboard da diretoria, ambos dados precisam ser convertido para horas em formato decimal. O impacto esperado é a padronização dos indicadores de desempenho (KPIs) para análise de ROI.
#
# **Tarefa:**
# Crie um sistema que receba o registro de 345 minutos e realize a transformação para a grandeza de horas decimais. O resultado deve refletir a fração exata do tempo de uso para que o custo por hora seja aplicado posteriormente. Exiba o valor convertido.

# %%
minutos_total = 345
horas = minutos_total // 60
minutos = minutos_total % 60
horas_decimais = minutos_total / 60

print(f"{horas}:{minutos} em horas decimais é {horas_decimais}")
# Out:
# 5:45 em horas decimais é 5.75

# %% [markdown]
# ### Exercício 15 – Telemetria Aeroespacial e Autonomia de Voo
# Um drone de monitoramento ambiental realizou dois voos de mapeamento um com duração de 3.77 horas enquanto o outro foram 214 minutos. No entanto, o sistema de telemetria de bateria processa o consumo de energia exclusivamente em segundos. Para calcular a energia total que a bateria deve ter, considere que cada segundo do drone corresponde à 2,7 joules. O impacto esperado é o cálculo preciso da energia necessária para evitar a perda do equipamento durante o pouso, adicionando 15% de margem de segurança.
#
# **Tarefa:**
# A partir do tempo de ambos os voos, desenvolva o raciocínio lógico para converter o total integralmente para a unidade de segundos, e obter quanto de energia foi gasto nos voos. Em seguida, considere a margem de segurança e armazene o resultado final em uma variável apropriada e exiba no terminal.

# %%
voos_em_minutos = [3.77 * 60, 214]
segundos_total_de_voo =  (voos_em_minutos[0] + voos_em_minutos[1]) * 60
consumo_por_segundo = 2.7
margem_seguranca = 15/100

energia_gasta = segundos_total_de_voo * consumo_por_segundo
energia_gasta_com_margem_seguranca = energia_gasta + (energia_gasta * margem_seguranca)

print(f"Energia necessária: {energia_gasta_com_margem_seguranca:.2f} Joules")
# Out:
# Energia necessária: 82009.26 Joules

# %% [markdown]
# ### Exercício 16 – Decomposição de Jornada para Fechamento de Folha
#
# Um técnico de som trabalhou em um set de filmagem por um total de 1527 minutos. Para o fechamento do contrato, o RH precisa que o tempo seja discriminado separando as horas completas dos minutos excedentes, pois as horas e os minutos possuem valores de pagamento distintos. O impacto esperado é a transparência e conformidade com os acordos sindicais. Para este contrato cada hora completa trabalhada é paga a R$ 60,00 e cada minuto excedente é pago a R$ 1,20. O impacto esperado é conseguir definir com precisão o valor que deverá ser pago.
#
# **Tarefa:** A partir do total de 1527 minutos, calcule a quantidade de horas inteiras trabalhadas e a quantidade de minutos restantes. Em seguida calcule o valor total referente às horas e o valor total referente aos minutos excedentes.
#
# Exiba no terminal devidamente sinalizada:
#    - horas trabalhadas
#    - minutos excedentes
#    - valor pago pelas horas
#    - valor pago pelos minutos
#    - valor total a receber

# %%
minutos_trabalhados = 1527
valor_hora_completa = 60.00
valor_minuto_excedente = 1.20

horas_trabalhadas = minutos_trabalhados // 60
minutos_excedentes = minutos_trabalhados % 60

valor_horas = horas_trabalhadas * valor_hora_completa
valor_minutos = minutos_excedentes * valor_minuto_excedente
valor_total = valor_horas + valor_minutos

print(f"Horas trabalhadas: {horas_trabalhadas}")
print(f"Minutos excedentes: {minutos_excedentes}")
print(f"Valor pago pelas horas: R$ {valor_horas:.2f}")
print(f"Valor pago pelos minutos: R$ {valor_minutos:.2f}")
print(f"Valor pago total: R$ {valor_total:.2f}")
# Out:
# Horas trabalhadas: 25
# Minutos excedentes: 27
# Valor pago pelas horas: R$ 1500.00
# Valor pago pelos minutos: R$ 32.40
# Valor pago total: R$ 1532.40

# %% [markdown]
# # Instruções para Entrega

# %% [markdown]
# ## Permissão Pública e Desligando assistente de IA

# %% [markdown]
# Primeiro é necessário ligar a permissão de compartilhamento com link e desligar o assistente de IA. Siga o procedimento:
# 1. Clique na foto do seu usuário no canto superior direito e depois selecione 'Account Settings'

# %% [markdown]
# <img src="image-20250206-210028.png" width="" align="" />

# %% [markdown]
# 2. Do lado esquerdo, selecione o seu workspace onde seu TP será colocado (no caso o workspace Meus Trabalhos foi selecionado)
# 3. Depois seleciona e opção 'Settings & members'

# %% [markdown]
# <img src="image-20250206-210139.png" width="" align="" />

# %% [markdown]
# 4. Clique em 'Project Settings'
# 5. Desmarque todas as opções relacionadas a IA
# 6. Ligue a opção 'Allow projects to be shared publicity'

# %% [markdown]
# <img src="image-20250206-210654.png" width="" align="" />

# %% [markdown]
# ## Criando Link para entregar

# %% [markdown]
# Assim que terminar, siga o procedimento:

# %% [markdown]
# 1) Primeiro clique em Duplicate para copiar o projeto
# 2) Clique em **Share** no canto superior direito.
# 2) Ao lado de "Anyone with a link to this project" clique e selecione a opção **"Edit"**.
# 3) Clique em "Copy Link" e guarde o link do seu projeto.
# 4) Crie um PDF com nome **nome_sobrenome_DR2_TP1.pdf** com o link do projeto e coloque faça o _upload_ no Moodle.

# %% [markdown]
# <img src="image-20250205-220400.png" width="" align="" />

# %% [markdown]
# <img src="image-20250205-220422.png" width="" align="" />
